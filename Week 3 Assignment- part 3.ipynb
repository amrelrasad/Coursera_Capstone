# %% [markdown]
# # Week 3 Assignment
# This note book is for 3rd week assignment of Applied Data Science Capstone course.
# The purpose of this assignment is to read an process data frame to extrct data from webpage.

# %%
#imports
import pandas as pd
import numpy as np

# %% [markdown]
# # Part 1: Read and process data from web

# %% [markdown]
# # 1. Read table from `wikipedia` page using `pandas` `read_html` function

# %%
page = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'    
wikitables = pd.read_html(page, index_col=0, attrs={"class":"wikitable"})     
#wikitables[0].to_csv('assignment1.csv')

# %%
#read data frame from table
df_can_n=wikitables[0]

# %% [markdown]
# # 2. Process Dataframe

# %%
#show head of dataframe
df_can_n.head()
# Out:
#                      1                 2
# 0
# Postcode       Borough     Neighbourhood
# M1A       Not assigned      Not assigned
# M2A       Not assigned      Not assigned
# M3A         North York         Parkwoods
# M4A         North York  Victoria Village

# %%
#rest index to swith postcode ino columns
df_can_n.reset_index( inplace=True)
#rename columns
df_can_n.columns=df_can_n.iloc[0,:]
#drop first row
df_can_n.drop(index=0,inplace=True)
# reset index to ensure continunity after dropped rows
df_can_n=df_can_n.reset_index(drop=True)
# drop not assigned Borough cells
df_can_n=df_can_n[df_can_n['Borough']!='Not assigned'].reset_index(drop=True)
# group neighbourhoods by postcode
df_can_n = df_can_n.groupby(['Postcode','Borough'])['Neighbourhood'].apply(', '.join).reset_index()
# dictionary for last row
last_row={'Postcode':df_can_n.shape[0],'Borough':'','Neighbourhood':''}
# append last row
df_can_n=df_can_n.append(last_row,ignore_index=True)

# %% [markdown]
# # 3. Show Dataframe

# %%
df_can_n
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# # Part 2- Geospatial Coordinates

# %% [markdown]
# # 1. Read geospacial dataframe

# %%
# read data frame
df_geo=pd.read_csv('Geospatial_Coordinates.csv')
# sort dataframe
df_geo=df_geo.sort_values(by='Postal Code')

# %% [markdown]
# # 2. Process and sort neighbourhod dataframe

# %%
# remove last row
df_can_n=df_can_n.iloc[0:102,:]
# sort dataframe
df_can_n=df_can_n.sort_values(by='Postcode')

# %% [markdown]
# # 3. Construct complete dataframe

# %%
# add Latitude column
df_can_n['Latitude']=df_geo['Latitude']
# add Longitude column
df_can_n['Longitude']=df_geo['Longitude']
# renmae Postcode column
df_can_n.rename(columns={'Postcode':'PostalCode'}, inplace=True)

# %% [markdown]
# # 4. View dataframe

# %%
df_can_n.head()
# Out:
#   PostalCode      Borough                           Neighbourhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# # Part 3: Clustering and generate map

# %% [markdown]
# # 1. Import sklearn and folium

# %%
#imports
from sklearn.cluster import KMeans
import folium

# %% [markdown]
# # 2. Create new dataframe for Toronto

# %%
# new data frame for Toronto
df_toronto = df_can_n.copy()
df_toronto = df_toronto[df_can_n.Borough.str.contains("Toronto")]
df_toronto.reset_index(inplace=True,drop=True)
df_toronto.head()
# Out:
#   PostalCode          Borough                   Neighbourhood   Latitude  \
# 0        M4E     East Toronto                     The Beaches  43.676357
# 1        M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2        M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 3        M4M     East Toronto                 Studio District  43.659526
# 4        M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude
# 0 -79.293031
# 1 -79.352188
# 2 -79.315572
# 3 -79.340923
# 4 -79.388790

# %% [markdown]
# # 3. Cluster neighbourhoods  base on GPS Coordinates and generate map

# %%
toronto_map = folium.Map(location=[43.65, -79.4], zoom_start=12)

x = df_toronto['Latitude']
y = df_toronto['Longitude']
packed_data = np.stack((x, y), axis=1)

kmeans = KMeans(n_clusters=4, random_state=0).fit(packed_data)

clusters = kmeans.labels_
colors = ['blue', 'red', 'green', 'black']
df_toronto['Cluster'] = clusters

for latitude, longitude, borough, cluster in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Cluster']):
    label = folium.Popup(borough, parse_html=True)
    folium.CircleMarker(
        [latitude, longitude],
        radius=8,
        popup=label,
        color='yellow',
        fill=True,
        fill_color=colors[cluster],
        fill_opacity=0.9).add_to(toronto_map)  

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
